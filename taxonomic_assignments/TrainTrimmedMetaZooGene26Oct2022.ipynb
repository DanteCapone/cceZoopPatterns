# %%
#import the qiime2 python module to allow for inline visualizations
import qiime2 as q2

#which version of qiime2 and python are we using?
# !qiime info
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #import the qiime2 python module to allow for inline visualizations
# ----> 2 import qiime2 as q2
#       4 #which version of qiime2 and python are we using?
#       5 get_ipython().system('qiime info')
#
# ModuleNotFoundError: No module named 'qiime2'

# %% [markdown]
# First import the COI data (trimmed), train the classifier, and test it on the mock sequences

# %%
#import the sequence data
# !qiime tools import \
  --type 'FeatureData[Sequence]' \
  --input-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/Leray_COI_MetaZooGene.fasta \
  --output-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/Leray_COI_MetaZooGene.qza

#import the taxonomy data
# !qiime tools import \
  --type 'FeatureData[Taxonomy]' \
  --input-format HeaderlessTSVTaxonomyFormat \
  --input-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-coi__MZGdbALL__o00__A_withCCESeqs.txt \
  --output-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-coi__MZGdbALL__o00__A.qza
# Out:
# Imported /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/Leray_COI_MetaZooGene.fasta as DNASequencesDirectoryFormat to /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/Leray_COI_MetaZooGene.qza
# Imported /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-coi__MZGdbALL__o00__A_withCCESeqs.txt as HeaderlessTSVTaxonomyFormat to /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-coi__MZGdbALL__o00__A.qza

# %%
#train classifier
# !qiime feature-classifier fit-classifier-naive-bayes \
  --i-reference-reads /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/Leray_COI_MetaZooGene.qza \
  --i-reference-taxonomy /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-coi__MZGdbALL__o00__A.qza \
  --o-classifier /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-leray-classifier_r_trimmed.qza
# Out:
# Saved TaxonomicClassifier to: /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-leray-classifier_r_trimmed.qza

# %%
#test it on the mock sequences
#!qiime tools import \
#  --type 'FeatureData[Sequence]' \
#  --input-path /Users/stephaniematthews/Desktop/UniqueCOI.fasta \
#  --output-path /Users/stephaniematthews/Documents/databases/mockCOI.qza

# !qiime feature-classifier classify-sklearn \
  --i-classifier /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-leray-classifier_r_trimmed.qza \
  --i-reads /Users/stephaniematthews/Documents/databases/mockCOI.qza \
  --o-classification /Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qza

# !qiime metadata tabulate \
  --m-input-file /Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qza \
  --o-visualization /Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qzv
# Out:
# Saved FeatureData[Taxonomy] to: /Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qza
# Saved Visualization to: /Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qzv

# %%
q2.Visualization.load('/Users/stephaniematthews/Documents/databases/mockCOI-taxonomy-leray_trimmed.qzv')
# Out:
# <visualization: Visualization uuid: 6728fb2a-45fc-43c0-8145-276ad56ba719>

# %% [markdown]
# Now import the 18S data (trimmed), train the classifier, and test it on the mock sequences

# %%
#import the sequence data
# !qiime tools import \
  --type 'FeatureData[Sequence]' \
  --input-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/ZHAN_18S_MetaZooGene.fasta \
  --output-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/ZHAN_18S_MetaZooGene.qza

#import the taxonomy data
# !qiime tools import \
  --type 'FeatureData[Taxonomy]' \
  --input-format HeaderlessTSVTaxonomyFormat \
  --input-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-18s__MZGdbALL__o00__A.txt \
  --output-path /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-18s__MZGdbALL__o00__A.qza
# Out:
# Imported /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/ZHAN_18S_MetaZooGene.fasta as DNASequencesDirectoryFormat to /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/ZHAN_18S_MetaZooGene.qza
# Imported /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-18s__MZGdbALL__o00__A.txt as HeaderlessTSVTaxonomyFormat to /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-18s__MZGdbALL__o00__A.qza

# %%
#train classifier
# !qiime feature-classifier fit-classifier-naive-bayes \
  --i-reference-reads /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/ZHAN_18S_MetaZooGene.qza \
  --i-reference-taxonomy /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZGmothur-18s__MZGdbALL__o00__A.qza \
  --o-classifier /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-zhan-classifier_r_trimmed.qza
# Out:
# Saved TaxonomicClassifier to: /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-zhan-classifier_r_trimmed.qza

# %%
#test it on the mock sequences
#!qiime tools import \
#  --type 'FeatureData[Sequence]' \
#  --input-path /Users/stephaniematthews/Desktop/UniqueCOI.fasta \
#  --output-path /Users/stephaniematthews/Documents/databases/mockCOI.qza

# !qiime feature-classifier classify-sklearn \
  --i-classifier /Users/stephaniematthews/Documents/databases/MetaZooGene26Oct2022/MZG-zhan-classifier_r_trimmed.qza \
  --i-reads /Users/stephaniematthews/Documents/databases/mock18S.qza \
  --o-classification /Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qza

# !qiime metadata tabulate \
  --m-input-file /Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qza \
  --o-visualization /Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qzv
# Out:
# Saved FeatureData[Taxonomy] to: /Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qza
# Saved Visualization to: /Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qzv

# %%
q2.Visualization.load('/Users/stephaniematthews/Documents/databases/mock18S-taxonomy-zhan_trimmed.qzv')
# Out:
# <visualization: Visualization uuid: 46c4a1e3-569a-4d3c-9a7e-5ddc5cf2b5f7>
